# %%
from langchain_openai import OpenAI

llm = OpenAI(
    model='deepseek-chat',
    api_key='sk-f8993f0875ee45288803c8104f219aae',
    base_url='https://api.deepseek.com'
)

input_text = 'The meaning of life is'
for chunk in llm.stream(input_text):
    print(chunk, end="")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 10
#       3 llm = OpenAI(
#       4     model_name='deepseek-chat',
#       5     api_key='sk-f8993f0875ee45288803c8104f219aae',
#       6     openai_api_base='https://api.deepseek.com'
#       7 )
#       9 input_text = 'The meaning of life is'
# ---> 10 for chunk in llm.stream(input_text):
#      11     print(chunk, end="")
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/langchain_core/language_models/llms.py:560, in BaseLLM.stream(self, input, config, stop, **kwargs)
#     558 generation: Optional[GenerationChunk] = None
#     559 try:
# --> 560     for chunk in self._stream(
#     561         prompt, stop=stop, run_manager=run_manager, **kwargs
#     562     ):
#     563         yield chunk.text
#     564         if generation is None:
#
# ...
